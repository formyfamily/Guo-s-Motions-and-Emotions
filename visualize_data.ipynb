# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
# %matplotlib inline
import matplotlib.pyplot as plt

dev_visual_features = np.load('data/dev_visual_features.npy')
dev_annotations = np.load('data/dev_annotations.npy')
dev_visual_features = sklearn.preprocessing.minmax_scale(dev_visual_features, feature_range=(0, 1), axis=0)

# %%
print(dev_visual_features.shape)
print(dev_annotations.shape)
dev_visual_features = pd.DataFrame(dev_visual_features)
dev_annotations = pd.DataFrame(dev_annotations)
# Out:
# (5274, 1271)
# (5274, 2)

# %%
dev_visual_features.describe()
# Out:
#               0            1            2            3            4     \
# count  5274.000000  5274.000000  5274.000000  5274.000000  5274.000000
# mean      0.810047     0.723613     0.657099     0.602107     0.700459
# std       0.213594     0.254598     0.269459     0.273103     0.276461
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.720000     0.573333     0.473333     0.406667     0.520000
# 50%       0.886667     0.800000     0.726667     0.653333     0.793333
# 75%       0.980000     0.933333     0.873333     0.826667     0.933333
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               5            6            7            8            9     \
# count  5274.000000  5274.000000  5274.000000  5274.000000  5274.000000
# mean      0.599501     0.534695     0.489465     0.694972     0.595395
# std       0.296607     0.301368     0.299042     0.277787     0.277573
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.366667     0.273333     0.226667     0.573333     0.420000
# 50%       0.660000     0.573333     0.513333     0.793333     0.666667
# 75%       0.860000     0.806667     0.760000     0.900000     0.813333
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           ...              1261         1262         1263         1264  \
# count     ...       5274.000000  5274.000000  5274.000000  5274.000000
# mean      ...          0.328445     0.294869     0.194862     0.369872
# std       ...          0.133199     0.108652     0.100988     0.145909
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...          0.243416     0.228370     0.125171     0.279239
# 50%       ...          0.326335     0.287487     0.188465     0.371105
# 75%       ...          0.416726     0.354188     0.256305     0.465803
# max       ...          1.000000     1.000000     1.000000     1.000000
#
#               1265         1266         1267         1268         1269  \
# count  5274.000000  5274.000000  5274.000000  5274.000000  5274.000000
# mean      0.443846     0.471368     0.403450     0.453185     0.371537
# std       0.145844     0.130500     0.170692     0.166506     0.158482
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.366730     0.402075     0.293432     0.359375     0.269202
# 50%       0.454395     0.477922     0.420551     0.470459     0.387072
# 75%       0.536862     0.550343     0.529131     0.571289     0.479468
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               1270
# count  5274.000000
# mean      0.317711
# std       0.136260
# min       0.000000
# 25%       0.227948
# 50%       0.301910
# 75%       0.390346
# max       1.000000
#
# [8 rows x 1271 columns]

# %%
dev_annotations.describe()
# Out:
#                  0            1
# count  5274.000000  5274.000000
# mean      0.000476     0.125717
# std       0.344513     0.288574
# min      -0.922164    -0.738475
# 25%      -0.231627    -0.089238
# 50%       0.011606     0.101995
# 75%       0.255190     0.328662
# max       0.845079     0.961575

# %%
plt.figure()
dev_annotations.hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111a31b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111afc390>]], dtype=object)

# %%
plt.figure()
dev_visual_features[[0,1]].hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x116bac080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124d59438>]], dtype=object)
